# %% [markdown]
# # Data ETL

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

from config import api_key

# %% [markdown]
# ### Store CSV into DataFrame
#     - CSV datasets were extracted from two (2) sources
#     - The first data source is the US Department of Labor - www.dol.gov
#         •	https://oui.doleta.gov/unemploy/DataDownloads.asp

# %%
# Reading the first csv file 
csv_file = "Resources/Labor_force.csv"

#Creating and displaying the DF
unemployment_data = pd.read_csv(csv_file)
unemployment_data.head()
# Out:
#                        State  IUR%  TUR%  Covered Employment  Labor Force  \
# 0  Alabama                     0.7   2.5                1,937       2,260
# 1  Alaska                      2.4   5.9                  314         343
# 2  Arizona                     0.6   4.3                2,818       3,611
# 3  Arkansas                    0.8   3.3                1,204       1,368
# 4  California                  1.7   3.7               17,392      19,598
#
#   Total Unemployment Insured Unemployment Total Unemployed
# 0               55.9                 14.3             14.3
# 1               20.2                  7.8              7.8
# 2              155.4                 17.4             17.4
# 3               44.6                   10               10
# 4              719.3                301.9            301.9

# %% [markdown]
#     - The second data source is the Bureau of Labor Statistics:
#         •	https://www.bls.gov/web/cewdat.supp.toc.htm

# %%
csv_file1 = "Resources/allhlcn191.csv"
employment_data = pd.read_csv(csv_file1, low_memory=False)
employment_data.head()
# Out:
#   Area\r\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type St Name        Area  \
# 0        US000  US   0.0    0     10  2019    1    Nation     NaN  U.S. TOTAL
# 1        US000  US   0.0    1     10  2019    1    Nation     NaN  U.S. TOTAL
# 2        US000  US   0.0    2     10  2019    1    Nation     NaN  U.S. TOTAL
# 3        US000  US   0.0    3     10  2019    1    Nation     NaN  U.S. TOTAL
# 4        US000  US   0.0    5     10  2019    1    Nation     NaN  U.S. TOTAL
#
#    ...                  Industry Status Code Establishment Count  \
# 0  ...  10 Total, all industries         NaN          10,128,767
# 1  ...  10 Total, all industries         NaN              59,786
# 2  ...  10 Total, all industries         NaN              69,738
# 3  ...  10 Total, all industries         NaN             170,833
# 4  ...  10 Total, all industries         NaN           9,828,410
#
#   January Employment February Employment March Employment  \
# 0        145,300,240         145,904,676      146,514,210
# 1          2,782,414           2,796,169        2,794,347
# 2          4,569,224           4,660,780        4,678,454
# 3         14,360,252          14,502,549       14,575,919
# 4        123,588,350         123,945,178      124,465,490
#
#   Total Quarterly Wages Average Weekly Wage  \
# 0     2,244,801,047,986               1,183
# 1        55,405,534,148               1,527
# 2        71,755,772,878               1,191
# 3       188,105,800,263                 999
# 4     1,929,533,940,697               1,197
#
#   Employment Location Quotient Relative to U.S.  \
# 0                                           1.0
# 1                                           1.0
# 2                                           1.0
# 3                                           1.0
# 4                                           1.0
#
#    Total Wage Location Quotient Relative to U.S.
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Cleaning up the DataFrames
#
# ### I. Unemployment Data

# %% [markdown]
#     - Selecting the columns to be displayed

# %%
new_unemployment_data_df = unemployment_data[['State','Labor Force','Total Unemployment','Insured Unemployment']].copy()
new_unemployment_data_df.head()
# Out:
#                        State Labor Force Total Unemployment  \
# 0  Alabama                         2,260               55.9
# 1  Alaska                            343               20.2
# 2  Arizona                         3,611              155.4
# 3  Arkansas                        1,368               44.6
# 4  California                     19,598              719.3
#
#   Insured Unemployment
# 0                 14.3
# 1                  7.8
# 2                 17.4
# 3                   10
# 4                301.9

# %% [markdown]
#     - Dropping null values

# %%
new_unemployment_data = new_unemployment_data_df.dropna()
new_unemployment_data
# Out:
#                         State Labor Force Total Unemployment  \
# 0   Alabama                         2,260               55.9
# 1   Alaska                            343               20.2
# 2   Arizona                         3,611              155.4
# 3   Arkansas                        1,368               44.6
# 4   California                     19,598              719.3
# 5   Colorado                        3,181               76.9
# 6   Connecticut                     1,928               64.2
# 7   Delaware                          492               18.1
# 8   District of Columbia              413               20.9
# 9   Florida                        10,502              286.9
# 10  Georgia                         5,135              148.3
# 11  Hawaii                            667               16.6
# 12  Idaho                             888               23.8
# 13  Illinois                        6,440              224.8
# 14  Indiana                         3,365                103
# 15  Iowa                            1,765               43.3
# 16  Kansas                          1,501               42.8
# 17  Kentucky                        2,083               79.6
# 18  Louisiana                       2,101              101.5
# 19  Maine                             690               18.2
# 20  Maryland                        3,292              103.2
# 21  Massachusetts                   3,843               91.6
# 22  Michigan                        4,935              168.8
# 23  Minnesota                       3,129               92.8
# 24  Mississippi                     1,283               68.1
# 25  Missouri                        3,122               92.7
# 26  Montana                           535               18.1
# 27  Nebraska                        1,044               29.2
# 28  Nevada                          1,568                 55
# 29  New Hampshire                     775               17.8
# 30  New Jersey                      4,568                155
# 31  New Mexico                        969                 44
# 32  New York                        9,524              356.5
# 33  North Carolina                  5,114                176
# 34  North Dakota                      402                8.1
# 35  Ohio                            5,818              222.6
# 36  Oklahoma                        1,840               61.1
# 37  Oregon                          2,109               66.8
# 38  Pennsylvania                    6,549              287.7
# 39  Puerto Rico                     1,051               93.1
# 40  Rhode Island                      561               17.4
# 41  South Carolina                  2,374               52.5
# 42  South Dakota                      470               14.9
# 43  Tennessee                       3,356              104.6
# 44  Texas                          14,228              471.7
# 45  Utah                            1,630               31.6
# 46  Vermont                           339                6.6
# 47  Virgin Islands                      0                  0
# 48  Virginia                        4,444              108.3
# 49  Washington                      3,968              157.3
# 50  West Virginia                     805               38.4
# 51  Wisconsin                       3,102               91.8
# 52  Wyoming                           293               10.2
# 53  United States                 165,374           5,577.70
#
#    Insured Unemployment
# 0                  14.3
# 1                   7.8
# 2                  17.4
# 3                    10
# 4                 301.9
# 5                  18.8
# 6                  29.2
# 7                   4.8
# 8                   6.8
# 9                  31.7
# 10                 25.1
# 11                  6.4
# 12                  5.5
# 13                 87.3
# 14                 18.7
# 15                 18.6
# 16                    8
# 17                 16.8
# 18                 11.1
# 19                  4.4
# 20                 23.1
# 21                 52.1
# 22                 48.6
# 23                 41.7
# 24                  6.3
# 25                 18.1
# 26                  6.9
# 27                  2.9
# 28                 16.7
# 29                  2.7
# 30                 85.5
# 31                  8.5
# 32                128.6
# 33                 17.3
# 34                  3.5
# 35                 47.1
# 36                   16
# 37                 26.1
# 38                101.8
# 39                   15
# 40                  6.8
# 41                 14.1
# 42                  1.4
# 43                 16.1
# 44                123.4
# 45                  7.9
# 46                  3.2
# 47                  0.5
# 48                 18.8
# 49                 49.3
# 50                 13.6
# 51                 28.1
# 52                  2.7
# 53             1,598.60

# %%
#unemployment_data_df = unemployment_data_df.reindex(columns=['State', 'IUR%', 'TUR%', 'Covered Employment', 'Total Unemployment'])
#new_unemployment_data = new_unemployment_data.set_index(new_unemployment_data['State'], inplace=False)
#del new_unemployment_data['State']
#new_unemployment_data.head()

# %% [markdown]
#     - Renaming columns and trimming spaces to be uploaded into PostgreSQL

# %%
new_unemployment_data.rename(columns={'Labor Force':'labor_force', 'Total Unemployment':'total_unemp','Insured Unemployment':'ins_unemp'}, inplace=True)
new_unemployment_data.head()
# Out:
# C:\Users\marib\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#                        State labor_force total_unemp ins_unemp
# 0  Alabama                         2,260        55.9      14.3
# 1  Alaska                            343        20.2       7.8
# 2  Arizona                         3,611       155.4      17.4
# 3  Arkansas                        1,368        44.6        10
# 4  California                     19,598       719.3     301.9

# %%
new_unemployment_data.to_csv(r'Resources\new_unemployment', index = False)

# %% [markdown]
# ### II. Employment Data

# %% [markdown]
#     - Selecting the columns to be displayed

# %%
new_employment_data_df = employment_data[['St Name','Ownership','Industry','Establishment Count','Total Quarterly Wages']].copy()
new_employment_data_df
# Out:
#       St Name           Ownership                                 Industry  \
# 0         NaN       Total Covered                 10 Total, all industries
# 1         NaN  Federal Government                 10 Total, all industries
# 2         NaN    State Government                 10 Total, all industries
# 3         NaN    Local Government                 10 Total, all industries
# 4         NaN             Private                 10 Total, all industries
# ...       ...                 ...                                      ...
# 62643     NaN             Private  1024 Professional and business services
# 62644     NaN             Private       1025 Education and health services
# 62645     NaN             Private             1026 Leisure and hospitality
# 62646     NaN             Private                      1027 Other services
# 62647     NaN             Private                        1029 Unclassified
#
#       Establishment Count Total Quarterly Wages
# 0              10,128,767     2,244,801,047,986
# 1                  59,786        55,405,534,148
# 2                  69,738        71,755,772,878
# 3                 170,833       188,105,800,263
# 4               9,828,410     1,929,533,940,697
# ...                   ...                   ...
# 62643                 429            69,137,911
# 62644                 421            98,166,254
# 62645                 326            31,938,215
# 62646                 233            10,763,796
# 62647                  26               103,654
#
# [62648 rows x 5 columns]

# %% [markdown]
#     - Dropping null values

# %%
new_employment_data = new_employment_data_df.dropna()
new_employment_data
# Out:
#        St Name           Ownership                                 Industry  \
# 18     Alabama       Total Covered                 10 Total, all industries
# 19     Alabama  Federal Government                 10 Total, all industries
# 20     Alabama    State Government                 10 Total, all industries
# 21     Alabama    Local Government                 10 Total, all industries
# 22     Alabama             Private                 10 Total, all industries
# ...        ...                 ...                                      ...
# 55938  Wyoming             Private  1024 Professional and business services
# 55939  Wyoming             Private       1025 Education and health services
# 55940  Wyoming             Private             1026 Leisure and hospitality
# 55941  Wyoming             Private                      1027 Other services
# 55942  Wyoming             Private                        1029 Unclassified
#
#       Establishment Count Total Quarterly Wages
# 18                127,988        24,160,364,990
# 19                  1,216         1,106,955,506
# 20                  1,381         1,249,405,799
# 21                  3,679         2,289,309,551
# 22                121,712        19,514,694,134
# ...                   ...                   ...
# 55938                 209            17,842,867
# 55939                  37             1,142,010
# 55940                   2                     0
# 55941                  26                     0
# 55942                   3                     0
#
# [55925 rows x 5 columns]

# %% [markdown]
#     - Renaming columns and trimming spaces to be uploaded into PostgreSQL

# %%
new_employment_data.rename(columns={'St Name':'state','Establishment Count':'est_count', 'Total Quarterly Wages':'tot_q1_wages'}, inplace=True)
new_employment_data
# Out:
#          state           Ownership                                 Industry  \
# 18     Alabama       Total Covered                 10 Total, all industries
# 19     Alabama  Federal Government                 10 Total, all industries
# 20     Alabama    State Government                 10 Total, all industries
# 21     Alabama    Local Government                 10 Total, all industries
# 22     Alabama             Private                 10 Total, all industries
# ...        ...                 ...                                      ...
# 55938  Wyoming             Private  1024 Professional and business services
# 55939  Wyoming             Private       1025 Education and health services
# 55940  Wyoming             Private             1026 Leisure and hospitality
# 55941  Wyoming             Private                      1027 Other services
# 55942  Wyoming             Private                        1029 Unclassified
#
#       est_count    tot_q1_wages
# 18      127,988  24,160,364,990
# 19        1,216   1,106,955,506
# 20        1,381   1,249,405,799
# 21        3,679   2,289,309,551
# 22      121,712  19,514,694,134
# ...         ...             ...
# 55938       209      17,842,867
# 55939        37       1,142,010
# 55940         2               0
# 55941        26               0
# 55942         3               0
#
# [55925 rows x 5 columns]

# %% [markdown]
#     - Extracting a 3rd table from the new_employment_data_df. The data contains not only employment information about each State and County, but on a Country level

# %%
# Locating the employment info for the US
us_employment_df = employment_data.loc[employment_data['St'] == "US"]
us_employment_df
# Out:
#    Area\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type St Name        Area  \
# 0       US000  US   0.0    0     10  2019    1    Nation     NaN  U.S. TOTAL
# 1       US000  US   0.0    1     10  2019    1    Nation     NaN  U.S. TOTAL
# 2       US000  US   0.0    2     10  2019    1    Nation     NaN  U.S. TOTAL
# 3       US000  US   0.0    3     10  2019    1    Nation     NaN  U.S. TOTAL
# 4       US000  US   0.0    5     10  2019    1    Nation     NaN  U.S. TOTAL
# 5       US000  US   0.0    5    101  2019    1    Nation     NaN  U.S. TOTAL
# 6       US000  US   0.0    5   1011  2019    1    Nation     NaN  U.S. TOTAL
# 7       US000  US   0.0    5   1012  2019    1    Nation     NaN  U.S. TOTAL
# 8       US000  US   0.0    5   1013  2019    1    Nation     NaN  U.S. TOTAL
# 9       US000  US   0.0    5    102  2019    1    Nation     NaN  U.S. TOTAL
# 10      US000  US   0.0    5   1021  2019    1    Nation     NaN  U.S. TOTAL
# 11      US000  US   0.0    5   1022  2019    1    Nation     NaN  U.S. TOTAL
# 12      US000  US   0.0    5   1023  2019    1    Nation     NaN  U.S. TOTAL
# 13      US000  US   0.0    5   1024  2019    1    Nation     NaN  U.S. TOTAL
# 14      US000  US   0.0    5   1025  2019    1    Nation     NaN  U.S. TOTAL
# 15      US000  US   0.0    5   1026  2019    1    Nation     NaN  U.S. TOTAL
# 16      US000  US   0.0    5   1027  2019    1    Nation     NaN  U.S. TOTAL
# 17      US000  US   0.0    5   1029  2019    1    Nation     NaN  U.S. TOTAL
#
#     ...                                   Industry Status Code  \
# 0   ...                   10 Total, all industries         NaN
# 1   ...                   10 Total, all industries         NaN
# 2   ...                   10 Total, all industries         NaN
# 3   ...                   10 Total, all industries         NaN
# 4   ...                   10 Total, all industries         NaN
# 5   ...                        101 Goods-producing         NaN
# 6   ...          1011 Natural resources and mining         NaN
# 7   ...                          1012 Construction         NaN
# 8   ...                         1013 Manufacturing         NaN
# 9   ...                      102 Service-providing         NaN
# 10  ...  1021 Trade, transportation, and utilities         NaN
# 11  ...                           1022 Information         NaN
# 12  ...                  1023 Financial activities         NaN
# 13  ...    1024 Professional and business services         NaN
# 14  ...         1025 Education and health services         NaN
# 15  ...               1026 Leisure and hospitality         NaN
# 16  ...                        1027 Other services         NaN
# 17  ...                          1029 Unclassified         NaN
#
#    Establishment Count January Employment February Employment  \
# 0           10,128,767        145,300,240         145,904,676
# 1               59,786          2,782,414           2,796,169
# 2               69,738          4,569,224           4,660,780
# 3              170,833         14,360,252          14,502,549
# 4            9,828,410        123,588,350         123,945,178
# 5            1,312,678         21,510,624          21,559,163
# 6              138,819          1,778,549           1,784,774
# 7              820,571          7,024,798           7,027,786
# 8              353,288         12,707,277          12,746,603
# 9            8,515,732        102,077,726         102,386,015
# 10           1,932,679         27,398,331          27,102,707
# 11             180,020          2,795,250           2,861,315
# 12             905,215          8,186,657           8,212,793
# 13           1,875,783         20,685,523          20,824,860
# 14           1,744,724         22,786,628          22,978,757
# 15             871,107         15,665,628          15,811,144
# 16             852,166          4,435,813           4,463,625
# 17             154,038            123,896             130,814
#
#    March Employment Total Quarterly Wages Average Weekly Wage  \
# 0       146,514,210     2,244,801,047,986               1,183
# 1         2,794,347        55,405,534,148               1,527
# 2         4,678,454        71,755,772,878               1,191
# 3        14,575,919       188,105,800,263                 999
# 4       124,465,490     1,929,533,940,697               1,197
# 5        21,712,671       375,692,634,070               1,338
# 6         1,812,323        31,158,986,336               1,338
# 7         7,145,999       109,576,096,988               1,193
# 8        12,754,349       234,957,550,746               1,419
# 9       102,752,819     1,553,841,306,627               1,167
# 10       27,107,336       344,566,061,505                 974
# 11        2,832,701        92,172,137,813               2,506
# 12        8,216,591       259,142,774,934               2,429
# 13       20,866,252       429,600,506,339               1,589
# 14       23,035,725       287,566,849,356                 965
# 15       16,063,480        94,959,797,601                 461
# 16        4,495,899        44,026,337,947                 758
# 17          134,835         1,806,841,132               1,070
#
#    Employment Location Quotient Relative to U.S.  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
# 5                                            1.0
# 6                                            1.0
# 7                                            1.0
# 8                                            1.0
# 9                                            1.0
# 10                                           1.0
# 11                                           1.0
# 12                                           1.0
# 13                                           1.0
# 14                                           1.0
# 15                                           1.0
# 16                                           1.0
# 17                                           1.0
#
#     Total Wage Location Quotient Relative to U.S.
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# 5                                             1.0
# 6                                             1.0
# 7                                             1.0
# 8                                             1.0
# 9                                             1.0
# 10                                            1.0
# 11                                            1.0
# 12                                            1.0
# 13                                            1.0
# 14                                            1.0
# 15                                            1.0
# 16                                            1.0
# 17                                            1.0
#
# [18 rows x 21 columns]

# %% [markdown]
#     - Selecting the columns to be displayed

# %%
us_employment = us_employment_df[['St','Ownership','Industry','Establishment Count','Total Quarterly Wages']].copy()
us_employment
# Out:
#     St           Ownership                                   Industry  \
# 0   US       Total Covered                   10 Total, all industries
# 1   US  Federal Government                   10 Total, all industries
# 2   US    State Government                   10 Total, all industries
# 3   US    Local Government                   10 Total, all industries
# 4   US             Private                   10 Total, all industries
# 5   US             Private                        101 Goods-producing
# 6   US             Private          1011 Natural resources and mining
# 7   US             Private                          1012 Construction
# 8   US             Private                         1013 Manufacturing
# 9   US             Private                      102 Service-providing
# 10  US             Private  1021 Trade, transportation, and utilities
# 11  US             Private                           1022 Information
# 12  US             Private                  1023 Financial activities
# 13  US             Private    1024 Professional and business services
# 14  US             Private         1025 Education and health services
# 15  US             Private               1026 Leisure and hospitality
# 16  US             Private                        1027 Other services
# 17  US             Private                          1029 Unclassified
#
#    Establishment Count Total Quarterly Wages
# 0           10,128,767     2,244,801,047,986
# 1               59,786        55,405,534,148
# 2               69,738        71,755,772,878
# 3              170,833       188,105,800,263
# 4            9,828,410     1,929,533,940,697
# 5            1,312,678       375,692,634,070
# 6              138,819        31,158,986,336
# 7              820,571       109,576,096,988
# 8              353,288       234,957,550,746
# 9            8,515,732     1,553,841,306,627
# 10           1,932,679       344,566,061,505
# 11             180,020        92,172,137,813
# 12             905,215       259,142,774,934
# 13           1,875,783       429,600,506,339
# 14           1,744,724       287,566,849,356
# 15             871,107        94,959,797,601
# 16             852,166        44,026,337,947
# 17             154,038         1,806,841,132

# %% [markdown]
#     - Renaming columns and trimming spaces to be uploaded into PostgreSQL

# %%
us_employment.rename(columns={'Ownership':'ownership', 'Establishment Count':'est_count', 
                              'Total Quarterly Wages':'tot_q1_wages'}, inplace=True)
us_employment
# Out:
#     St           ownership                                   Industry  \
# 0   US       Total Covered                   10 Total, all industries
# 1   US  Federal Government                   10 Total, all industries
# 2   US    State Government                   10 Total, all industries
# 3   US    Local Government                   10 Total, all industries
# 4   US             Private                   10 Total, all industries
# 5   US             Private                        101 Goods-producing
# 6   US             Private          1011 Natural resources and mining
# 7   US             Private                          1012 Construction
# 8   US             Private                         1013 Manufacturing
# 9   US             Private                      102 Service-providing
# 10  US             Private  1021 Trade, transportation, and utilities
# 11  US             Private                           1022 Information
# 12  US             Private                  1023 Financial activities
# 13  US             Private    1024 Professional and business services
# 14  US             Private         1025 Education and health services
# 15  US             Private               1026 Leisure and hospitality
# 16  US             Private                        1027 Other services
# 17  US             Private                          1029 Unclassified
#
#      est_count       tot_q1_wages
# 0   10,128,767  2,244,801,047,986
# 1       59,786     55,405,534,148
# 2       69,738     71,755,772,878
# 3      170,833    188,105,800,263
# 4    9,828,410  1,929,533,940,697
# 5    1,312,678    375,692,634,070
# 6      138,819     31,158,986,336
# 7      820,571    109,576,096,988
# 8      353,288    234,957,550,746
# 9    8,515,732  1,553,841,306,627
# 10   1,932,679    344,566,061,505
# 11     180,020     92,172,137,813
# 12     905,215    259,142,774,934
# 13   1,875,783    429,600,506,339
# 14   1,744,724    287,566,849,356
# 15     871,107     94,959,797,601
# 16     852,166     44,026,337,947
# 17     154,038      1,806,841,132

# %% [markdown]
# ### Connect to local database

# %%
#rds_connection_string = "<postgres>:<pwd>@localhost:5432/unemploy_insDB"
#engine = create_engine(f'postgresql://{rds_connection_string}')
#conn = engine.connect()

# %%
DB_URI = 'postgres+psycopg2://postgres:'+api_key+'@localhost:5432/unemploy_insDB'
engine = create_engine(DB_URI)
conn = engine.connect()

# %%
#check for tables
engine.table_names()
# Out:
# ['unemployment', 'employment', 'us_employment']

# %%
#Use pandas to load csv converted DataFrame into database
new_unemployment_data.to_sql(name='unemployment', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from unemployment', con=engine).head()
# Out:
#                   State labor_force total_unemp ins_unemp
# 0  Alabama                    2,260        55.9      14.3
# 1  Alaska                       343        20.2       7.8
# 2  Arizona                    3,611       155.4      17.4
# 3  Arkansas                   1,368        44.6        10
# 4  California                19,598       719.3     301.9

# %%
#Use pandas to load csv converted DataFrame into database
new_employment_data.to_sql(name= 'employment', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from employment', con=engine).head()
# Out:
#      state           Ownership                  Industry est_count  \
# 0  Alabama       Total Covered  10 Total, all industries   127,988
# 1  Alabama  Federal Government  10 Total, all industries     1,216
# 2  Alabama    State Government  10 Total, all industries     1,381
# 3  Alabama    Local Government  10 Total, all industries     3,679
# 4  Alabama             Private  10 Total, all industries   121,712
#
#      tot_q1_wages
# 0  24,160,364,990
# 1   1,106,955,506
# 2   1,249,405,799
# 3   2,289,309,551
# 4  19,514,694,134

# %%
#Use pandas to load csv converted DataFrame into database
new_employment_data.to_sql(name= 'us_employment', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from us_employment', con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb36d15f1929> in <module>
# ----> 1 pd.read_sql_query('select * from us_employment', con=engine).head()
#
# NameError: name 'pd' is not defined
